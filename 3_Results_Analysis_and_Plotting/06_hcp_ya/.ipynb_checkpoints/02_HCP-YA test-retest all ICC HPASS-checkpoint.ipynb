# %%
import os
import pandas as pd
import numpy as np
import pingouin as pg
import seaborn as sns; sns.set_theme()
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Load data

# %%
path_img_out = '/media/hcs-psy-narun/Alina/HCP_results/predicted_values_for_datasets_5/plots_article/plots_feat_hcpya/'

# %%
pth ='/media/hcs-psy-narun/Alina/HCP_YA/retest/MLtables_cope/output_retest_new_enh_newADJ_new_sets_newRest_CogTotalComp_Unadj/'

# %% [markdown]
# #### Stacked models

# %%
#load tables with stacked y_pred
dff1 = pd.read_csv(pth+'3level_retest1_y_pred_stacked.csv', index_col=0)
dff2 = pd.read_csv(pth+'3level_retest2_y_pred_stacked.csv', index_col=0)

# %% [markdown]
# ##### Calculate ICC (stacked)

# %%
#reorganize the table and calculate ICC
i = 0
dct_icc={}
while i < len(dff1.columns):
    #create tables for pingouin format
    df1=dff1.iloc[:,i]
    df2=dff2.iloc[:,i]
    df_comp = pd.DataFrame({'subj': np.append(df1.index, df2.index),
                            'trial': np.append(np.full(len(df1.index), 1), np.full(len(df2.index), 2)),
                            'scores': np.array(pd.concat([df1, df2], axis=0))})
    
    icc_table = pg.intraclass_corr(data = df_comp, targets='subj', raters='trial', ratings='scores')
    
    dct_icc[dff1.iloc[:,i].name] = pd.Series({'ICC2' : icc_table.iloc[1,2], 
                                              'ICC3' : icc_table.iloc[2,2],
                                              'CI2' : icc_table.iloc[1,7], 
                                              'CI3' : icc_table.iloc[2,7]} )
    
    i+=1
    
df_icc = pd.DataFrame(dct_icc).T

# %%
#labels
labels = [ 
'Stacked: All', #1
'Stacked: Task Contrast',         #2
'Stacked: Non Task', #3
'Stacked: Task FC',#4
'Stacked: Task Contrast & Task FC',#5
'Stacked: All excluding Task FC',#6
'Stacked: All excluding Task Contrast',#7
'Stacked: Resting and Task FC' #8
]

# %%
df_icc.index = labels

# %%
df_icc.sort_values(by='ICC3', ascending=False)
# Out:
#                                           ICC2      ICC3           CI2  \
# Stacked: Non Task                      0.89072  0.891429  [0.79, 0.94]
# Stacked: All excluding Task Contrast  0.814524  0.809994   [0.66, 0.9]
# Stacked: Task Contrast & Task FC      0.769196  0.798096  [0.55, 0.88]
# Stacked: All                          0.764142  0.793204  [0.54, 0.88]
# Stacked: All excluding Task FC        0.740313  0.791859  [0.44, 0.88]
# Stacked: Task Contrast                0.723446  0.773251  [0.43, 0.87]
# Stacked: Resting and Task FC          0.778031   0.77293   [0.6, 0.88]
# Stacked: Task FC                      0.770205  0.764894  [0.59, 0.88]
#
#                                                CI3
# Stacked: Non Task                     [0.79, 0.94]
# Stacked: All excluding Task Contrast   [0.65, 0.9]
# Stacked: Task Contrast & Task FC      [0.63, 0.89]
# Stacked: All                          [0.62, 0.89]
# Stacked: All excluding Task FC        [0.62, 0.89]
# Stacked: Task Contrast                [0.59, 0.88]
# Stacked: Resting and Task FC          [0.59, 0.88]
# Stacked: Task FC                      [0.58, 0.88]

# %% [markdown]
# #### Single modality models

# %%
#load tables with stacked y_pred
dff1s = pd.read_csv(pth+'3level_retest1_y_pred_singleML.csv', index_col=0)
dff2s = pd.read_csv(pth+'3level_retest2_y_pred_singleML.csv', index_col=0)

# %% [markdown]
# ##### Calculate ICC (single)

# %%
#reorganize the table and calculate ICC
i = 0
dct_iccs={}
while i < len(dff1s.columns):
    #create tables for pingouin format
    df1=dff1s.iloc[:,i]
    df2=dff2s.iloc[:,i]
    df_comp = pd.DataFrame({'subj': np.append(df1.index, df2.index),
                            'trial': np.append(np.full(len(df1.index), 1), np.full(len(df2.index), 2)),
                            'scores': np.array(pd.concat([df1, df2], axis=0))})
    
    icc_table = pg.intraclass_corr(data = df_comp, targets='subj', raters='trial', ratings='scores')
    
    dct_iccs[dff1s.iloc[:,i].name] = pd.Series({'ICC2' : icc_table.iloc[1,2], 
                                                'ICC3' : icc_table.iloc[2,2],
                                                'CI2' : icc_table.iloc[1,7], 
                                                'CI3' : icc_table.iloc[2,7]} )
    
    i+=1
    
df_iccs = pd.DataFrame(dct_iccs).T
# Out:
# /home/narunlab/anaconda3/lib/python3.7/site-packages/pingouin/parametric.py:1006: RuntimeWarning: divide by zero encountered in double_scalars
#   fval = msbetween / mserror
# /home/narunlab/anaconda3/lib/python3.7/site-packages/pingouin/reliability.py:314: RuntimeWarning: divide by zero encountered in double_scalars
#   icc3 = (msb - mse) / (msb + (k - 1) * mse)
# /home/narunlab/anaconda3/lib/python3.7/site-packages/pingouin/reliability.py:320: RuntimeWarning: divide by zero encountered in double_scalars
#   f1k = msb / msw
# /home/narunlab/anaconda3/lib/python3.7/site-packages/pingouin/reliability.py:354: RuntimeWarning: invalid value encountered in double_scalars
#   l1 = (f1l - 1) / (f1l + (k - 1))
# /home/narunlab/anaconda3/lib/python3.7/site-packages/pingouin/reliability.py:355: RuntimeWarning: invalid value encountered in double_scalars
#   u1 = (f1u - 1) / (f1u + (k - 1))
# /home/narunlab/anaconda3/lib/python3.7/site-packages/pingouin/reliability.py:367: RuntimeWarning: invalid value encountered in double_scalars
#   l2 = n * (msb - f2u * mse) / (f2u * (k * msj + (k * n - k - n) * mse) + n * msb)

# %%
#labels
labelss = [
'Emotion Processing Contrast',
'Gambling Contrast',
'Language Contrast',
'Motor Contrast', 
'Relational Contrast',
'Social Cognition Contrast', 
'Working Memory Contrast',
    
'Gambling FC',
'Language FC',
'Motor FC',
'Relational FC',
'Social Cognition FC',
'Working Memory FC',    
    
'Cortical Thickness',
'Subcortical Volume',          
'Surface Area', 
'Resting State FC', 
'Total Brain Volume'    
]

# %%
df_iccs.index = labelss

# %%
df_iccs.sort_values(by='ICC3', ascending=False)
# Out:
#                                  ICC2      ICC3           CI2           CI3
# Gambling Contrast                 1.0       inf    [nan, 1.0]   [-3.0, 3.0]
# Total Brain Volume           0.995673  0.996461   [0.99, 1.0]   [0.99, 1.0]
# Surface Area                 0.960501  0.959673  [0.92, 0.98]  [0.92, 0.98]
# Subcortical Volume           0.930967  0.929288  [0.87, 0.96]  [0.86, 0.96]
# Cortical Thickness           0.897604  0.895823  [0.81, 0.95]   [0.8, 0.95]
# Language Contrast            0.756686  0.775016  [0.56, 0.87]   [0.6, 0.88]
# Resting State FC             0.766861  0.772126  [0.58, 0.88]  [0.59, 0.88]
# Language FC                  0.698064   0.69645  [0.48, 0.84]  [0.47, 0.84]
# Working Memory Contrast      0.659157  0.687955   [0.4, 0.82]  [0.46, 0.83]
# Relational Contrast          0.565351  0.562292  [0.29, 0.76]  [0.28, 0.75]
# Working Memory FC            0.564405  0.559193  [0.28, 0.76]  [0.28, 0.75]
# Social Cognition Contrast    0.556024  0.548912  [0.27, 0.75]  [0.26, 0.75]
# Gambling FC                   0.53494  0.527945  [0.24, 0.74]  [0.24, 0.73]
# Social Cognition FC          0.511613  0.516196  [0.22, 0.72]  [0.22, 0.73]
# Relational FC                0.495352  0.507661   [0.2, 0.71]  [0.21, 0.72]
# Motor FC                      0.47547  0.468447   [0.16, 0.7]  [0.16, 0.69]
# Emotion Processing Contrast   0.39885  0.426589  [0.09, 0.64]  [0.11, 0.67]
# Motor Contrast               0.388962  0.381911  [0.06, 0.64]  [0.06, 0.63]

# %%
#drop gambling from the table
df_iccs = df_iccs.dropna(axis=0)
df_iccs = df_iccs.drop('Gambling Contrast', axis=0)

# %% [markdown]
# ##### Concat icc tables into one

# %%
pd.concat([df_iccs, df_icc], axis=0).sort_values(by="ICC3", ascending=False)
# Out:
#                                           ICC2      ICC3           CI2  \
# Total Brain Volume                    0.995673  0.996461   [0.99, 1.0]
# Surface Area                          0.960501  0.959673  [0.92, 0.98]
# Subcortical Volume                    0.930967  0.929288  [0.87, 0.96]
# Cortical Thickness                    0.897604  0.895823  [0.81, 0.95]
# Stacked: Non Task                      0.89072  0.891429  [0.79, 0.94]
# Stacked: All excluding Task Contrast  0.814524  0.809994   [0.66, 0.9]
# Stacked: Task Contrast & Task FC      0.769196  0.798096  [0.55, 0.88]
# Stacked: All                          0.764142  0.793204  [0.54, 0.88]
# Stacked: All excluding Task FC        0.740313  0.791859  [0.44, 0.88]
# Language Contrast                     0.756686  0.775016  [0.56, 0.87]
# Stacked: Task Contrast                0.723446  0.773251  [0.43, 0.87]
# Stacked: Resting and Task FC          0.778031   0.77293   [0.6, 0.88]
# Resting State FC                      0.766861  0.772126  [0.58, 0.88]
# Stacked: Task FC                      0.770205  0.764894  [0.59, 0.88]
# Language FC                           0.698064   0.69645  [0.48, 0.84]
# Working Memory Contrast               0.659157  0.687955   [0.4, 0.82]
# Relational Contrast                   0.565351  0.562292  [0.29, 0.76]
# Working Memory FC                     0.564405  0.559193  [0.28, 0.76]
# Social Cognition Contrast             0.556024  0.548912  [0.27, 0.75]
# Gambling FC                            0.53494  0.527945  [0.24, 0.74]
# Social Cognition FC                   0.511613  0.516196  [0.22, 0.72]
# Relational FC                         0.495352  0.507661   [0.2, 0.71]
# Motor FC                               0.47547  0.468447   [0.16, 0.7]
# Emotion Processing Contrast            0.39885  0.426589  [0.09, 0.64]
# Motor Contrast                        0.388962  0.381911  [0.06, 0.64]
#
#                                                CI3
# Total Brain Volume                     [0.99, 1.0]
# Surface Area                          [0.92, 0.98]
# Subcortical Volume                    [0.86, 0.96]
# Cortical Thickness                     [0.8, 0.95]
# Stacked: Non Task                     [0.79, 0.94]
# Stacked: All excluding Task Contrast   [0.65, 0.9]
# Stacked: Task Contrast & Task FC      [0.63, 0.89]
# Stacked: All                          [0.62, 0.89]
# Stacked: All excluding Task FC        [0.62, 0.89]
# Language Contrast                      [0.6, 0.88]
# Stacked: Task Contrast                [0.59, 0.88]
# Stacked: Resting and Task FC          [0.59, 0.88]
# Resting State FC                      [0.59, 0.88]
# Stacked: Task FC                      [0.58, 0.88]
# Language FC                           [0.47, 0.84]
# Working Memory Contrast               [0.46, 0.83]
# Relational Contrast                   [0.28, 0.75]
# Working Memory FC                     [0.28, 0.75]
# Social Cognition Contrast             [0.26, 0.75]
# Gambling FC                           [0.24, 0.73]
# Social Cognition FC                   [0.22, 0.73]
# Relational FC                         [0.21, 0.72]
# Motor FC                              [0.16, 0.69]
# Emotion Processing Contrast           [0.11, 0.67]
# Motor Contrast                        [0.06, 0.63]

# %% [markdown]
# ##### Plot ICC

# %%
df_plot = pd.concat([df_iccs, df_icc], axis=0).sort_values(by="ICC3", ascending=False)

#for mtype in ['svr_', 'rf_', 'xgb_', 'eNet_']:
#df_plot = df_icc

#mt_index = [i for i in df_icc.index if mtype in i]
#df_plot = df_plot.reindex(index=mt_index)

inum = len(df_plot.index)+2

sns.set_color_codes()
fig, ax = plt.subplots(figsize=(10,10))
ax.grid(False)
#plt.figure(figsize=(10,7))
sns.set_style("ticks")
"""for i in range(len(df_plot.index)):
    y = df_plot.sort_values(by="ICC2", ascending=False).index[i]
    x = df_plot.loc[y,'ICC2']
    xerr = abs(df_plot.loc[y,'CI2'].reshape(2,1) - x)
    #plt.errorbar(x=x, y=(len(df_plot.index)-i)+0.15, xerr=xerr, marker='o',capsize=5, color='blue', label="ICC2")
    if i==0:
        fig = plt.errorbar(x=x, y=(len(df_plot.index)-i)+0.15, xerr=xerr, marker='o',capsize=5, color='b', label="ICC(2,1)")
    else:
        fig = plt.errorbar(x=x, y=(len(df_plot.index)-i)+0.15, xerr=xerr, marker='o',capsize=5, color='b')"""

for i in range(len(df_plot.index)):
    y = df_plot.sort_values(by="ICC3", ascending=False).index[i]
    x = df_plot.loc[y,'ICC3']
    xerr = abs(df_plot.loc[y,'CI3'].reshape(2,1) - x)
    #plt.errorbar(x=x, y=(len(df_plot.index)-i)-0.15, xerr=xerr, marker='o',capsize=5, color='red', label="ICC3") 
    if i==0:
        fig = plt.errorbar(x=x, y=(len(df_plot.index)-i)-0.15, xerr=xerr, marker='o',capsize=5, color='black', 
                           label="ICC")
    else:
        fig = plt.errorbar(x=x, y=(len(df_plot.index)-i)-0.15, xerr=xerr, marker='o',capsize=5, color='black')

plt.axvline(x=0.75, ymax=inum, c='green', linestyle=':')
plt.axvline(x=0.6, ymax=inum, c='orange', linestyle=':')
plt.axvline(x=0.4, ymax=inum, c='red', linestyle=':')
plt.axvline(x=0, ymax=inum, c='black', linestyle=':', linewidth=3)

ax.margins(0)
ax.axvspan(xmin=-0.6, xmax = 0.4, ymax=inum, facecolor='red', alpha=0.2, label='poor ICC level')
ax.axvspan(xmin=0.4, xmax = 0.6, ymax=inum, facecolor='orange', alpha=0.2, label='fair ICC level')
ax.axvspan(xmin=0.6, xmax = 0.75, ymax=inum, facecolor='yellow', alpha=0.2,label='good ICC level')
ax.axvspan(xmin=0.75, xmax = 1.1, ymax=inum, facecolor='green', alpha=0.2,label='excellent ICC level')

plt.xlim((-0.6, 1.1))

plt.xticks(np.arange(-0.6, 1.1, 0.1).round(2).tolist(), fontsize=20, rotation=45)
plt.yticks(range(0,inum,1), 
           np.append(np.append(np.array([' ']), np.array(df_plot.sort_values(by="ICC3", ascending=True).index)),
                     np.array([' '])), fontsize=23)
plt.legend(fontsize=20,loc='upper left', framealpha=1)
#plt.title('Test-Retest Reliability of\nPredicted General Cognition Scores', 
#          fontsize=32, loc='left')

plt.savefig(path_img_out+'icc_all_mods_plot_image.svg',bbox_inches='tight')

plt.show()

# %% [markdown]
# ##### Plot sessions values

# %%
dff1.columns = labels
dff2.columns = labels

dff1s.columns = labelss
dff2s.columns = labelss

# %%
run1 = pd.concat([dff1, dff1s], axis=1)
run2 = pd.concat([dff2, dff2s], axis=1)

# %%
fig = plt.figure(figsize=(18,21.5))
i=1
for col in df_plot['ICC3'].sort_values(ascending=False).index:
    plt.subplot(5, 5, i)
    pdf = pd.DataFrame(pd.concat([run1[col], run2[col]], axis=0))
    pdf['sessions'] = np.concatenate((np.full(len(run1[col]), 1), np.full(len(run1[col]), 2)), axis=0)
    pdf = pdf.reset_index()


    sns.pointplot(data=pdf, x='sessions', y=col, hue='index')
    plt.legend([],[], frameon=False)
    
    plt.ylabel('', fontsize=18) #'Predicted values'
    plt.xlabel('Sessions', fontsize=18)
    plt.xticks(fontsize=18)
    plt.yticks(fontsize=18)
    if 'Stacked:' in col:
        col = col.replace("Stacked: ", "Stacked:\n")
        if 'Task Contrast & Task FC' in col:
            col = col.replace("Task Contrast & Task FC", "Task Contrast &\nTask FC")
        if 'All excluding Task Contrast' in col:    
            col = col.replace("All excluding Task Contrast", "All excluding\nTask Contrast")
    if 'Contrast' in col:        
        if 'Working Memory Contrast' in col:    
            col = col.replace("Working Memory Contrast", "Working Memory\nContrast")  
        if 'Social Cognition Contrast' in col:    
            col = col.replace("Social Cognition Contrast", "Social Cognition\nContrast") 
        if 'Emotion Processing Contrast' in col:    
            col = col.replace("Emotion Processing Contrast", "Emotion Processing\nContrast")             
    plt.title(col, fontsize=24)
    i+=1
fig.tight_layout()

plt.savefig(path_img_out+'icc_all_mods_sessions_plot_image.svg',bbox_inches='tight')

plt.show()
