# %%
import pandas as pd
import numpy as np
import os
import glob
import seaborn as sns
import nibabel as nib
import nilearn.plotting as plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import hcp_utils as hcp

# %% [markdown]
# ##### Path var

# %%
source_dir = '/media/hcs-psy-narun/HCP-YA-retest-BIDS/derivatives/xcp_d-0.4.0rc2+16/xcp_d/'

# %%
os.makedirs('/media/hcs-psy-narun/HCP-YA_new_rest_RETEST_connectivity/signals')

# %%
out_dir = '/media/hcs-psy-narun/HCP-YA_new_rest_RETEST_connectivity/signals/'

# %%
out_tab = '/media/hcs-psy-narun/HCP-YA_new_rest_RETEST_connectivity/'

# %% [markdown]
# ##### Load data

# %%
labels_reord = np.append(pd.Series(hcp.mmp.labels)[1:].values[180:-19], pd.Series(hcp.mmp.labels)[1:].values[0:180])
labels_reord = np.append(labels_reord, sorted(pd.Series(hcp.mmp.labels)[1:].values[-19:]))

# %%
#read subject IDs
subIDs = [i.split('/')[-2].split('-')[-1] for i in (sorted(glob.glob(source_dir+'sub-*/')))]

# %%
main_ids = np.array(pd.read_csv('/media/hcs-psy-narun/Alina/HCP_YA_retest_id.csv', header=None).values.ravel(), dtype=str)

# %%
len(main_ids)
# Out:
# 34

# %% [markdown]
# ##### Read cifti files, extract signals and save them as a files

# %%
#dct_signls = {}

for subID in main_ids:
    
    #dct_signls[subID] = {}
    
    os.mkdir(out_dir +subID)
    path_out = out_dir+str(subID)+'/'
    
    files = sorted(glob.glob(source_dir+'sub-'+subID+'/func/'+'*rest_dir-*'+'denoised_bold.dtseries.nii'))
    
    for file in files:
        
        
        img = nib.load(file) #load file
        X = img.get_fdata() #load series to nibabel
        Xn = hcp.normalize(X) #normalize series
        Xp = hcp.parcellate(Xn, hcp.mmp) #apply Glasser parcellation
        Xdf = pd.DataFrame(Xp, columns=pd.Series(hcp.mmp.labels)[1:].values)  #extract timeseries into table
        Xdfr = Xdf.reindex(columns = labels_reord) #reorder index as in our previous data
        Xdfr = Xdfr.iloc[:,:-19] #replace subcortex from glasser with the same subcortex got with another command
        subcortex = {}
        for subc in list(hcp.struct.keys())[4:]:
            txt = 'hcp.struct.'+str(subc)
            subcortex[subc] = pd.DataFrame(Xn[:, eval(txt)]).T.mean().values
        sbcr =   pd.DataFrame(subcortex)  

        Xdfr1 = pd.concat([Xdfr, sbcr], axis=1)
        
        
        
        Xdfr1.to_csv(path_out+str(subID)+'_'+file.split('/')[-1].split('_')[1].split('-')[1]+'_'+file.split('/')[-1].split('_')[3].replace('-','')+'_'+file.split('/')[-1].split('_')[2].split('-')[1]+'.csv')
        
        #dct_signls[subID][file.split('/')[-1].split('_')[1].split('-')[1]+'_'+file.split('/')[-1].split('_')[3].replace('-','')+'_'+file.split('/')[-1].split('_')[2].split('-')[1]] = Xdfr1
# Out:
# /home/narunlab/anaconda3/lib/python3.7/site-packages/hcp_utils/hcp_utils.py:456: RuntimeWarning: invalid value encountered in true_divide
#   return (X - np.mean(X,axis=0))/np.std(X,axis=0)

# %% [markdown]
# ##### Load saved files into dictionary

# %%
dct_signls = {}

for subID in main_ids:
    
    dct_signls[subID] = {}
    
    files = sorted(glob.glob(out_dir+subID+'/'+'*'+'.csv'))
    
    for file in files:
        
        dct_signls[subID][('_').join(file.split('/')[-1].split('.')[0].split('_')[2:])] = pd.read_csv(file, index_col=0)

# %%
#check the length
len(dct_signls.keys())
# Out:
# 34

# %%
#check the number of runs(files)
len(dct_signls['103818'].keys())
# Out:
# 4

# %%
#check for missing files

for key in dct_signls.keys():
    if len(dct_signls[key].keys()) !=4:
        print(key)
        print(dct_signls[key].keys())

# %% [markdown]
# ##### Concat 4 files into 1 signal table

# %%
for key in dct_signls.keys():
    tbls = sorted(dct_signls[key].keys())
    df_ = dct_signls[key][tbls[0]]
    for nm in tbls[1:]:
        df_ = pd.concat([df_, dct_signls[key][nm]], axis=0, ignore_index=True)
    dct_signls[key] = df_

# %% [markdown]
# ##### calculate the correlation matrix, flatten them into one row

# %%
#calculate correlation matrix for each task, flatten them into one row


dct_mat_str = {}

for subID in sorted(dct_signls.keys()):
    
    df = dct_signls[subID]

    Xdfr_cor = df.corr() #create correlational matrix
    Xdfr_corZ = np.arctanh(Xdfr_cor) #r-to-z
    #transform matrix to string for the subject
    dfg = Xdfr_corZ.where(np.triu(np.ones(Xdfr_corZ.shape), k=1).astype(bool)).stack().reset_index()
    indx = [i+'_&_'+j for i,j in zip(dfg['level_0'], dfg['level_1'])]
    fc_string = pd.Series(np.array(dfg[0]),index=indx) #a vector-like data for upper part of cor.matrix


    dct_mat_str[subID] = fc_string
            
df_rest_ = pd.DataFrame(dct_mat_str)

# %%
df_rest_.T
# Out:
#         R_V1_&_R_MST  R_V1_&_R_V6  R_V1_&_R_V2  R_V1_&_R_V3  R_V1_&_R_V4  \
# 103818      0.318335     0.371497     0.977259     0.765622     0.609599
# 105923      0.306039     0.665930     1.153015     0.909500     0.718358
# 114823      0.178502     0.599634     0.929645     0.841252     0.695489
# 115320      0.243321     0.664069     0.938495     0.824216     0.640275
# 122317      0.184334     0.572013     0.858446     0.440449     0.518291
# 125525      0.223584     0.646363     1.283646     0.874860     0.684737
# 135528     -0.087057     0.211434     0.682886     0.725520     0.606852
# 137128      0.099656     0.115489     0.626239     0.560205     0.592218
# 139839      0.242122     0.701285     1.061345     1.018767     0.664719
# 143325      0.280068     0.485030     0.950883     0.796806     0.566182
# 146129      0.305823     0.460456     1.006768     0.877901     0.617836
# 149337      0.204075     0.334866     0.940971     0.793057     0.476426
# 149741      0.467972     0.857914     1.231712     0.859348     0.779063
# 151526      0.148716     0.498852     0.916180     0.780143     0.506767
# 158035      0.322695     0.552921     0.913845     0.725888     0.489352
# 172332      0.236631     0.766015     1.094521     0.919708     0.704472
# 185442      0.346194     0.369104     0.942580     0.686916     0.284460
# 187547      0.365681     0.653781     0.750239     0.808805     0.599594
# 192439      0.351892     0.491807     1.211796     0.978566     0.890224
# 194140      0.182017     0.610636     1.190068     0.696188     0.378587
# 195041      0.195174     0.534699     1.030280     0.778706     0.511397
# 200109      0.162932     0.565014     0.840343     0.755250     0.622408
# 200614      0.117120     0.620200     0.991292     0.819902     0.664702
# 103818                       0.111112                        0.165683
# 105923                       0.061612                        0.093120
# 114823                       0.041944                        0.094836
# 115320                       0.076011                        0.135443
# 122317                       0.095881                        0.095007
# 125525                       0.054583                        0.117353
# 135528                       0.081076                        0.121600
# 137128                       0.069603                        0.113414
# 139839                       0.093094                        0.126892
# 143325                       0.114764                        0.133628
# 146129                       0.051738                        0.040520
# 149337                       0.045559                        0.097084
# 149741                       0.117048                        0.158292
# 151526                       0.081669                        0.091843
# 158035                       0.071408                        0.120094
# 172332                       0.072312                        0.121989
# 185442                       0.051355                        0.089266
# 187547                       0.055509                        0.125291
# 192439                       0.082425                        0.137604
# 194140                       0.064637                        0.086877
# 195041                       0.041387                        0.090459
# 200109                       0.073986                        0.106955
# 200614                       0.025975                        0.060580
# 204521                       0.009948                        0.078705
# 250427                       0.149507                        0.155580
# 287248                       0.038606                        0.107511
# 562345                       0.015087                        0.198519
# 599671                       0.075250                        0.087056
# 601127                       0.060037                        0.078818
# 660951                       0.021492                        0.085371
# 783462                       0.046405                        0.079101
# 859671                       0.055163                        0.107124
# 861456                       0.060249                        0.088085
# 917255                       0.031971                        0.082749
#
#         pallidum_right_&_thalamus_left  pallidum_right_&_thalamus_right  \
# 103818                        0.084324                         0.090713
# 105923                        0.079260                         0.065281
# 114823                        0.004115                         0.031112
# 115320                        0.035382                         0.056853
# 122317                        0.055365                         0.047611
# 125525                        0.059908                         0.052150
# 135528                        0.082980                         0.099322
# 137128                        0.040775                         0.051924
# 139839                        0.100560                         0.058611
# 143325                        0.070051                         0.088134
# 146129                        0.027731                         0.042662
# 149337                        0.012014                         0.027053
# 149741                        0.088212                         0.120003
# 151526                        0.036722                         0.080390
# 158035                        0.051755                         0.057224
# 172332                        0.051563                         0.078672
# 185442                        0.050210                         0.021757
# 187547                        0.112373                         0.086201
# 192439                        0.119671                         0.097548
# 194140                        0.027409                         0.064346
# 195041                        0.057853                         0.047768
# 200109                        0.084264                         0.061269
# 200614                        0.054644                         0.115885
# 204521                        0.007292                         0.042183
# 250427                        0.111101                         0.141731
# 287248                        0.092047                         0.131758
# 562345                        0.098240                         0.142068
# 599671                        0.112230                         0.101455
# 601127                        0.052799                         0.034876
# 660951                        0.027906                         0.063274
# 783462                        0.053019                         0.079755
# 859671                        0.094949                         0.086350
# 861456                        0.073525                         0.109898
# 917255                        0.073536                         0.079941
#
#         putamen_left_&_putamen_right  putamen_left_&_thalamus_left  \
# 103818                      0.547254                      0.279958
# 105923                      0.407841                      0.197837
# 114823                      0.406820                      0.236082
# 115320                      0.296924                      0.176611
# 122317                      0.422293                      0.211570
# 125525                      0.288651                      0.177789
# 135528                      0.279148                      0.317547
# 137128                      0.357561                      0.144312
# 139839                      0.450047                      0.251213
# 143325                      0.494495                      0.291612
# 146129                      0.376791                      0.206760
# 149337                      0.359928                      0.148703
# 149741                      0.530948                      0.378463
# 151526                      0.329230                      0.220424
# 158035                      0.214123                      0.125652
# 172332                      0.503139                      0.271664
# 185442                      0.354647                      0.202503
# 187547                      0.544333                      0.222644
# 192439                      0.350544                      0.256248
# 194140                      0.523877                      0.171456
# 195041                      0.319925                      0.053984
# 200109                      0.368619                      0.222850
# 200614                      0.376029                      0.195697
# 204521                      0.132820                      0.170124
# 250427                      0.244429                      0.281753
# 287248                      0.360747                      0.190824
# 562345                      0.225222                      0.146072
# 599671                      0.405605                      0.115218
# 601127                      0.383041                      0.240649
# 660951                      0.269202                      0.050083
# 783462                      0.357839                      0.193119
# 859671                      0.377540                      0.141119
# 861456                      0.285858                      0.188406
# 917255                      0.354191                      0.207982
#
#         putamen_left_&_thalamus_right  putamen_right_&_thalamus_left  \
# 103818                       0.270655                       0.224086
# 105923                       0.160214                       0.187853
# 114823                       0.221880                       0.190647
# 115320                       0.146843                       0.159915
# 122317                       0.216656                       0.230774
# 125525                       0.138547                       0.114700
# 135528                       0.268785                       0.276295
# 137128                       0.152249                       0.158621
# 139839                       0.237952                       0.228533
# 143325                       0.279678                       0.231064
# 146129                       0.138989                       0.172118
# 149337                       0.150126                       0.126453
# 149741                       0.255304                       0.301715
# 151526                       0.177501                       0.206468
# 158035                       0.097926                       0.066446
# 172332                       0.253923                       0.235138
# 185442                       0.174843                       0.197602
# 187547                       0.247337                       0.242412
# 192439                       0.226187                       0.248377
# 194140                       0.148374                       0.144403
# 195041                       0.101877                       0.040567
# 200109                       0.222724                       0.220538
# 200614                       0.107292                       0.175101
# 204521                       0.090386                       0.096886
# 250427                       0.249890                       0.126764
# 287248                       0.087170                       0.121904
# 562345                       0.057096                       0.210187
# 599671                       0.125311                       0.128982
# 601127                       0.215277                       0.230460
# 660951                       0.073380                       0.077060
# 783462                       0.147847                       0.115664
# 859671                       0.146497                       0.137111
# 861456                       0.189727                       0.130749
# 917255                       0.183994                       0.236181
#
#         putamen_right_&_thalamus_right  thalamus_left_&_thalamus_right
# 103818                        0.269526                        0.491691
# 105923                        0.212835                        0.395685
# 114823                        0.205004                        0.445037
# 115320                        0.124140                        0.214738
# 122317                        0.259950                        0.547424
# 125525                        0.170712                        0.267332
# 135528                        0.296032                        0.363564
# 137128                        0.182366                        0.322391
# 139839                        0.236047                        0.228301
# 143325                        0.252037                        0.381451
# 146129                        0.155057                        0.190605
# 149337                        0.144194                        0.191451
# 149741                        0.339437                        0.362264
# 151526                        0.267139                        0.351694
# 158035                        0.124022                        0.276169
# 172332                        0.255343                        0.310153
# 185442                        0.210184                        0.284981
# 187547                        0.288186                        0.351442
# 192439                        0.240228                        0.342563
# 194140                        0.150371                        0.315911
# 195041                        0.082464                        0.301867
# 200109                        0.224284                        0.271986
# 200614                        0.134880                        0.359612
# 204521                        0.087775                        0.220742
# 250427                        0.193692                        0.441907
# 287248                        0.126535                        0.331654
# 562345                        0.229251                        0.394790
# 599671                        0.159269                        0.361986
# 601127                        0.256139                        0.337225
# 660951                        0.112751                        0.206435
# 783462                        0.152739                        0.181847
# 859671                        0.193222                        0.318808
# 861456                        0.134241                        0.347519
# 917255                        0.198304                        0.306399
#
# [34 rows x 71631 columns]

# %% [markdown]
# ##### Save

# %%
df_rest_.T.to_csv(out_tab+'Rest_FC_retest_group_z_full.csv')
